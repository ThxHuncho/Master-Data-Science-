# %%
data <- read.csv(file = './Country-data.csv', sep=',')

# %%
data
# Out:
#     country                        child_mort exports health imports income
# 1   Afghanistan                     90.2      10.00    7.58  44.9     1610
# 2   Albania                         16.6      28.00    6.55  48.6     9930
# 3   Algeria                         27.3      38.40    4.17  31.4    12900
# 4   Angola                         119.0      62.30    2.85  42.9     5900
# 5   Antigua and Barbuda             10.3      45.50    6.03  58.9    19100
# 6   Argentina                       14.5      18.90    8.10  16.0    18700
# 7   Armenia                         18.1      20.80    4.40  45.3     6700
# 8   Australia                        4.8      19.80    8.73  20.9    41400
# 9   Austria                          4.3      51.30   11.00  47.8    43200
# 10  Azerbaijan                      39.2      54.30    5.88  20.7    16000
# 11  Bahamas                         13.8      35.00    7.89  43.7    22900
# ...

# %%
install.packages(c("FactoMineR", "factoextra"))
# Out:
# also installing the dependencies 'processx', 'rprojroot', 'diffobj', 'rematch2', 'brio', 'callr', 'cli', 'desc', 'pkgload', 'praise', 'ps', 'waldo', 'withr', 'glue', 'testthat', 'isoband', 'rlang', 'dplyr', 'lifecycle', 'vctrs', 'cpp11', 'ellipsis', 'pillar', 'SparseM', 'MatrixModels', 'sp', 'minqa', 'nloptr', 'RcppEigen', 'viridisLite', 'ggplot2', 'tidyr', 'broom', 'tibble', 'corrplot', 'tidyselect', 'carData', 'pbkrtest', 'quantreg', 'maptools', 'lme4', 'crosstalk', 'jquerylib', 'viridis', 'ggsci', 'cowplot', 'ggsignif', 'gridExtra', 'polynom', 'rstatix', 'car', 'DT', 'ellipse', 'flashClust', 'leaps', 'scatterplot3d', 'ggrepel', 'abind', 'dendextend', 'ggpubr'
#   There are binary versions available but the source versions are later:
#             binary   source needs_compilation
# diffobj      0.3.4    0.3.5              TRUE
# brio         1.1.2    1.1.3              TRUE
# cli          2.5.0    3.1.1              TRUE
# desc         1.3.0    1.4.0             FALSE
# ...

# %%
data[2:10]
# Out:
#     child_mort exports health imports income inflation life_expec total_fer
# 1    90.2      10.00    7.58  44.9     1610   9.440    56.2       5.82
# 2    16.6      28.00    6.55  48.6     9930   4.490    76.3       1.65
# 3    27.3      38.40    4.17  31.4    12900  16.100    76.5       2.89
# 4   119.0      62.30    2.85  42.9     5900  22.400    60.1       6.16
# 5    10.3      45.50    6.03  58.9    19100   1.440    76.8       2.13
# 6    14.5      18.90    8.10  16.0    18700  20.900    75.8       2.37
# 7    18.1      20.80    4.40  45.3     6700   7.770    73.3       1.69
# 8     4.8      19.80    8.73  20.9    41400   1.160    82.0       1.93
# 9     4.3      51.30   11.00  47.8    43200   0.873    80.5       1.44
# 10   39.2      54.30    5.88  20.7    16000  13.800    69.1       1.92
# 11   13.8      35.00    7.89  43.7    22900  -0.393    73.8       1.86
# 12    8.6      69.50    4.97  50.9    41100   7.440    76.0       2.16
# ...

# %%
library(FactoMineR)
acp=PCA(data[2:10])

# %%
acp
# Out:
# **Results for the Principal Component Analysis (PCA)**
# The analysis was performed on 167 individuals, described by 9 variables
# *The results are available in the following objects:
#
#    name               description
# 1  "$eig"             "eigenvalues"
# 2  "$var"             "results for the variables"
# 3  "$var$coord"       "coord. for the variables"
# 4  "$var$cor"         "correlations variables - dimensions"
# 5  "$var$cos2"        "cos2 for the variables"
# 6  "$var$contrib"     "contributions of the variables"
# 7  "$ind"             "results for the individuals"
# 8  "$ind$coord"       "coord. for the individuals"
# 9  "$ind$cos2"        "cos2 for the individuals"
# 10 "$ind$contrib"     "contributions of the individuals"
# 11 "$call"            "summary statistics"
# 12 "$call$centre"     "mean of the variables"
# 13 "$call$ecart.type" "standard error of the variables"
# 14 "$call$row.w"      "weights for the individuals"
# ...

# %%
summary(acp)
# Out:
# Call:
# PCA(X = data[2:10])
#
#
# Eigenvalues
#                        Dim.1   Dim.2   Dim.3   Dim.4   Dim.5   Dim.6   Dim.7
# Variance               4.136   1.546   1.170   0.995   0.661   0.224   0.113
# % of var.             45.952  17.182  13.004  11.053   7.340   2.484   1.260
# Cumulative % of var.  45.952  63.133  76.138  87.191  94.531  97.015  98.276
#                        Dim.8   Dim.9
# Variance               0.088   0.067
# % of var.              0.981   0.743
# Cumulative % of var.  99.257 100.000
#
# Individuals (the 10 first)
#                Dist    Dim.1    ctr   cos2    Dim.2    ctr   cos2    Dim.3
# 1          |  3.230 | -2.913  1.229  0.814 |  0.096  0.004  0.001 | -0.718
# 2          |  1.473 |  0.430  0.027  0.085 | -0.588  0.134  0.160 | -0.333
# 3          |  1.664 | -0.285  0.012  0.029 | -0.455  0.080  0.075 |  1.222
# 4          |  3.900 | -2.932  1.245  0.565 |  1.696  1.113  0.189 |  1.525
# ...

# %%
plot(acp)
# Out:
# plot without title

# %%
plot(acp,choix="var")
# Out:
# plot without title
